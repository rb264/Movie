# %%
import pandas as pd
import numpy as np

# %%
nepali = pd.read_csv('nepali_movies.csv')

# %%
nepali.head(5)
# Out:
#                                  imdb_url                    title    year  \
# 0   https://www.imdb.com/title/tt7229666/          Chhakka Panja 2  2017.0
# 1   https://www.imdb.com/title/tt8393764/          Chhakka Panja 3  2018.0
# 2   https://www.imdb.com/title/tt7672868/      Intu Mintu Londonma  2018.0
# 3  https://www.imdb.com/title/tt10942220/  Kabaddi Kabaddi Kabaddi  2019.0
# 4   https://www.imdb.com/title/tt8387542/                  Captain  2019.0
#
#    runtime                   genre  rating  votes  \
# 0  138 min           Comedy, Drama     6.6  290.0
# 1      NaN                  Comedy     6.3   96.0
# 2  120 min                 Romance     7.3   71.0
# 3      NaN  Comedy, Drama, Romance     8.6    9.0
# 4      NaN            Drama, Sport     3.2   46.0
#
#                                                 plot
# 0  Chhakka Panja 2 continues with new story of Ra...
# 1  When she learns about the worst condition of t...
# ...

# %%
del nepali["imdb_url"]

# %%
nepali.head(5)
# Out:
#                      title    year  runtime                   genre  rating  \
# 0          Chhakka Panja 2  2017.0  138 min           Comedy, Drama     6.6
# 1          Chhakka Panja 3  2018.0      NaN                  Comedy     6.3
# 2      Intu Mintu Londonma  2018.0  120 min                 Romance     7.3
# 3  Kabaddi Kabaddi Kabaddi  2019.0      NaN  Comedy, Drama, Romance     8.6
# 4                  Captain  2019.0      NaN            Drama, Sport     3.2
#
#    votes                                               plot
# 0  290.0  Chhakka Panja 2 continues with new story of Ra...
# 1   96.0  When she learns about the worst condition of t...
# 2   71.0  When Ishan (Dhiraj Magar) and Meera (Samragyee...
# 3    9.0                                         Add a Plot
# 4   46.0  Father's dedication to guiding his son to beco...

# %%
nepali.to_csv('final_data.csv',index=False)
